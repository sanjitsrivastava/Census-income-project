# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv")
data
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
data.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
#Categorical Data Visualization
data_visualization_nominal=data[['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
       'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
       'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
       'Income']].copy()

# %%
data=sns.countplot(x='Workclass',data=data_visualization_nominal)
print(data_visualization_nominal['Workclass'].value_counts())
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
data=sns.countplot(x='Workclass',hue='Income',data=data_visualization_nominal)
print(data_visualization_nominal['Workclass'].value_counts())
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
data=sns.countplot(x='Marital_status',data=data_visualization_nominal)
print(data_visualization_nominal['Marital_status'].value_counts())
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %%
data=sns.countplot(x='Occupation',data=data_visualization_nominal)
print(data_visualization_nominal['Occupation'].value_counts())
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
data=sns.countplot(x='Relationship',data=data_visualization_nominal)
print(data_visualization_nominal['Relationship'].value_counts())
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
data=sns.countplot(x='Race',data=data_visualization_nominal)
print(data_visualization_nominal['Race'].value_counts())
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64

# %%
data=sns.countplot(x='Sex',data=data_visualization_nominal)
print(data_visualization_nominal['Sex'].value_counts())
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %%
data=sns.countplot(x='Native_country',data=data_visualization_nominal)
print(data_visualization_nominal['Native_country'].value_counts())
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
data=sns.countplot(x='Sex',hue='Income',data=data_visualization_nominal)
print(data_visualization_nominal['Sex'].value_counts())
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %%
sns.scatterplot(x="Capital_gain",y='Income',data=data)
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Income'>

# %%
sns.catplot(x="Capital_loss",y="Income",data=data)

# %%
plt.hist(data['Native_country'],color='green',bins=30)
plt.show()

# %%
plt.hist(data['Hours_per_week'],color='green',bins=30)
plt.show()

# %%
data_visualization_continuous=data[['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
       'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
       'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
       'Income']].copy()

# %%
sns.displot(data, x="Hours_per_week", hue="Income", element="step")

# %%
sns.displot(data, x="Age", hue="Income", element="step")

# %%
sns.displot(data, x="Education_num", hue="Income", element="step")

# %%
sns.displot(data_visualization_continuous['Fnlwgt'],kde=True)

# %%
sns.displot(data, x="Fnlwgt", hue="Income", element="step")

# %%
sns.displot(data_visualization_continuous['Age'],kde=True)

# %%
sns.pairplot(data)

# %%
#encoding dataframe
from sklearn.preprocessing import OrdinalEncoder
data_1=OrdinalEncoder()
for i in data.columns:
    if data[i].dtypes=='object':
        data[i]=data_1.fit_transform(data[i].values.reshape(-1,1))
data
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50        6.0   83311        9.0             13             2.0
# 1       38        4.0  215646       11.0              9             0.0
# 2       53        4.0  234721        1.0              7             2.0
# 3       28        4.0  338409        9.0             13             2.0
# 4       37        4.0  284582       12.0             14             2.0
# ...    ...        ...     ...        ...            ...             ...
# 32555   27        4.0  257302        7.0             12             2.0
# 32556   40        4.0  154374       11.0              9             2.0
# 32557   58        4.0  151910       11.0              9             6.0
# 32558   22        4.0  201490       11.0              9             4.0
# 32559   52        5.0  287927       11.0              9             2.0
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
data.describe()
# Out:
#                 Age     Workclass        Fnlwgt     Education  Education_num  \
# count  32560.000000  32560.000000  3.256000e+04  32560.000000   32560.000000
# mean      38.581634      3.868796  1.897818e+05     10.298249      10.080590
# std       13.640642      1.455879  1.055498e+05      3.870317       2.572709
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      4.000000  1.178315e+05      9.000000       9.000000
# 50%       37.000000      4.000000  1.783630e+05     11.000000      10.000000
# 75%       48.000000      4.000000  2.370545e+05     12.000000      12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000      16.000000
#
#        Marital_status    Occupation  Relationship          Race           Sex  \
# count    32560.000000  32560.000000  32560.000000  32560.000000  32560.000000
# mean         2.611794      6.572912      1.446376      3.665848      0.669195
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.describe(), annot=True, linewidth=.5,linecolor='yellow')
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.003786 -0.076646  -0.010508       0.036527
# Workclass       0.003786   1.000000 -0.016587   0.023537       0.052015
# Fnlwgt         -0.076646  -0.016587  1.000000  -0.028156      -0.043159
# Education      -0.010508   0.023537 -0.028156   1.000000       0.359172
# Education_num   0.036527   0.052015 -0.043159   0.359172       1.000000
# Marital_status -0.266292  -0.064798  0.028184  -0.038398      -0.069338
# Occupation     -0.020946   0.255004  0.001554  -0.021274       0.109748
# Relationship   -0.263698  -0.090449  0.008922  -0.010879      -0.094145
# Race            0.028718   0.049720 -0.021278   0.014135       0.031825
# Sex             0.088832   0.095942  0.026882  -0.027349       0.012256
# Capital_gain    0.077674   0.033828  0.000437   0.030047       0.122627
# Capital_loss    0.057775   0.012231 -0.010259   0.016744       0.079932
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data.corr(), annot=True, linewidth=1,linecolor='yellow')
# Out:
# <AxesSubplot:>

# %%
data.corr()['Income'].sort_values()
# Out:
# Relationship     -0.250924
# Marital_status   -0.199295
# Fnlwgt           -0.009481
# Native_country    0.015845
# Workclass         0.051645
# Race              0.071853
# Occupation        0.075448
# Education         0.079311
# Capital_loss      0.150523
# Sex               0.215995
# Capital_gain      0.223333
# Hours_per_week    0.229690
# Age               0.234039
# Education_num     0.335182
# Income            1.000000
# Name: Income, dtype: float64

# %%
plt.figure(figsize=(12,10))
data.corr()['Income'].sort_values(ascending=False).drop(['Income']).plot(kind='bar',color='purple')
plt.xlabel('Income_data',fontsize=14)
plt.ylabel('column with target names',fontsize=16)
plt.title('correlation',fontsize=20)
plt.show()

# %%
data.shape
# Out:
# (32560, 15)

# %%
#to check outliers
import warnings
warnings.filterwarnings("ignore")
collist=data.columns.values
ncol=2
nrows=8
plt.figure(figsize=(nrows,3*nrows))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data[collist[i]])
    plt.tight_layout()

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(data))
threshold=3
np.where(z>3)
# Out:
# (array([    3,     9,    10, ..., 32532, 32550, 32552]),
#  array([13, 12,  8, ...,  8,  8,  8]))

# %%
np.abs(zscore(data))<0
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
data_new=data[(z<3).all(axis=1)]
data_new
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50        6.0   83311        9.0             13             2.0
# 1       38        4.0  215646       11.0              9             0.0
# 2       53        4.0  234721        1.0              7             2.0
# 4       37        4.0  284582       12.0             14             2.0
# 5       49        4.0  160187        6.0              5             3.0
# ...    ...        ...     ...        ...            ...             ...
# 32555   27        4.0  257302        7.0             12             2.0
# 32556   40        4.0  154374       11.0              9             2.0
# 32557   58        4.0  151910       11.0              9             6.0
# 32558   22        4.0  201490       11.0              9             4.0
# 32559   52        5.0  287927       11.0              9             2.0
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
#to know the percentage loss
loss_data=((32560-27417)/32560)*100
loss_data
# Out:
# 15.795454545454547

# %%
data.skew().sort_values()
# Out:
# Native_country    -3.658235
# Race              -2.435332
# Education         -0.934063
# Workclass         -0.752280
# Sex               -0.719244
# Education_num     -0.311630
# Marital_status    -0.013448
# Occupation         0.114540
# Hours_per_week     0.227636
# Age                0.558738
# Relationship       0.786784
# Income             1.212383
# Fnlwgt             1.446972
# Capital_loss       4.594549
# Capital_gain      11.953690
# dtype: float64

# %%
#distribution plot to check skewness
collist=data.columns.values
ncol=3
nrows=12
plt.figure(figsize=(nrows,5*nrows))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(data[collist[i]])
    plt.tight_layout()

# %%
x=data.drop("Income",axis=1)
y=["Income"]

# %%
x.skew().sort_values()
# Out:
# Native_country    -3.658235
# Race              -2.435332
# Education         -0.934063
# Workclass         -0.752280
# Sex               -0.719244
# Education_num     -0.311630
# Marital_status    -0.013448
# Occupation         0.114540
# Hours_per_week     0.227636
# Age                0.558738
# Relationship       0.786784
# Fnlwgt             1.446972
# Capital_loss       4.594549
# Capital_gain      11.953690
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
x=pd.DataFrame(x_new,columns=x.columns)
x.skew().sort_values()
# Out:
# Native_country   -2.725467
# Race             -2.010817
# Sex              -0.719244
# Education        -0.309431
# Occupation       -0.187152
# Marital_status   -0.114201
# Age              -0.013897
# Fnlwgt            0.016914
# Education_num     0.023885
# Workclass         0.061629
# Relationship      0.122917
# Hours_per_week    0.229556
# Capital_gain      3.016951
# Capital_loss      4.299511
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[ 0.89100917,  1.63902392, -1.08809975, ..., -0.2212132 ,
#         -2.27432962,  0.25196704],
#        [ 0.09486014,  0.01473675,  0.39389872, ..., -0.2212132 ,
#         -0.02241499,  0.25196704],
#        [ 1.06607549,  0.01473675,  0.55882797, ..., -0.2212132 ,
#         -0.02241499,  0.25196704],
#        ...,
#        [ 1.34101817,  0.01473675, -0.22544688, ..., -0.2212132 ,
#         -0.02241499,  0.25196704],
#        [-1.35173699,  0.01473675,  0.26617787, ..., -0.2212132 ,
#         -1.68191822,  0.25196704],
#        [ 1.00861719,  0.79497555,  0.98267517, ..., -0.2212132 ,
#         -0.02241499,  0.25196704]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.89100917,  1.63902392, -1.08809975, ..., -0.2212132 ,
#         -2.27432962,  0.25196704],
#        [ 0.09486014,  0.01473675,  0.39389872, ..., -0.2212132 ,
#         -0.02241499,  0.25196704],
#        [ 1.06607549,  0.01473675,  0.55882797, ..., -0.2212132 ,
#         -0.02241499,  0.25196704],
#        ...,
#        [ 1.34101817,  0.01473675, -0.22544688, ..., -0.2212132 ,
#         -0.02241499,  0.25196704],
#        [-1.35173699,  0.01473675,  0.26617787, ..., -0.2212132 ,
#         -1.68191822,  0.25196704],
#        [ 1.00861719,  0.79497555,  0.98267517, ..., -0.2212132 ,
#         -0.02241499,  0.25196704]])

# %%
x=data_new.iloc[:,:-1]
y=data_new.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lr=LogisticRegression()

# %%
maxAccu=0
minRs=0
for i in range(0,50):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    predict=lr.predict(x_test)
    acc=accuracy_score(y_test,predict)
    
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
    print("Best Accuracy is:-",maxAccu,"on random state",maxRs)
# Out:
# Best Accuracy is:- 0.8043763676148796 on random state 0
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# Best Accuracy is:- 0.8064186725018235 on random state 1
# ...

# %%
from sklearn.metrics import confusion_matrix,classification_report
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=9)
print("Accuracy",accuracy_score(y_test,predict)*100)
print(classification_report(y_test,predict))
print(confusion_matrix(y_test,predict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bced3193e9f9> in <module>
#       1 from sklearn.metrics import confusion_matrix,classification_report
# ----> 2 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=9)
#       3 print("Accuracy",accuracy_score(y_test,predict)*100)
#       4 print(classification_report(y_test,predict))
#       5 print(confusion_matrix(y_test,predict))
#
# NameError: name 'train_test_split' is not defined

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier()
dtc.fit(x_test,y_test)
preddtc=dtc.predict(x_test)
print("Accuracy",accuracy_score(y_test,predict)*100)
print(classification_report(y_test,predict))
print(confusion_matrix(y_test,predict))
# Out:
# Accuracy 74.58789204959884
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.93      0.85      5382
#          1.0       0.24      0.09      0.13      1473
#
#     accuracy                           0.75      6855
#    macro avg       0.52      0.51      0.49      6855
# weighted avg       0.67      0.75      0.70      6855
#
# [[4984  398]
#  [1344  129]]

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
rfc.fit(x_test,y_test)
predrfc=rfc.predict(x_test)
print("Accuracy",accuracy_score(y_test,predict)*100)
print(classification_report(y_test,predict))
print(confusion_matrix(y_test,predict))
# Out:
# Accuracy 74.58789204959884
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.93      0.85      5382
#          1.0       0.24      0.09      0.13      1473
#
#     accuracy                           0.75      6855
#    macro avg       0.52      0.51      0.49      6855
# weighted avg       0.67      0.75      0.70      6855
#
# [[4984  398]
#  [1344  129]]

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print("Accuracy",accuracy_score(y_test,predsvc)*100)
print(classification_report(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
# Out:
# Accuracy 81.72137126185265
#               precision    recall  f1-score   support
#
#          0.0       0.81      1.00      0.90      5382
#          1.0       0.98      0.15      0.26      1473
#
#     accuracy                           0.82      6855
#    macro avg       0.89      0.58      0.58      6855
# weighted avg       0.85      0.82      0.76      6855
#
# [[5377    5]
#  [1248  225]]

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(lr,x,y,cv=10)
print("Cv score of logistic Regression Model is:-",scr.mean()*100)
# Out:
# Cv score of logistic Regression Model is:- 80.20210297689327

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(dtc,x,y,cv=10)
print("Cv score of Decision Tree Classifier is:-",scr.mean()*100)
# Out:
# Cv score of Decision Tree Classifier is:- 80.7091040740454

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(rfc,x,y,cv=10)
print("Cv score of Random Forest Classifier is:-",scr.mean()*100)
# Out:
# Cv score of Random Forest Classifier is:- 85.23182427683892

# %%
pred_lr=lr.predict(x_test)
lss=accuracy_score(y_test,pred_)
lss_score=cross_val_score(lr,x,y,cv=10).mean()
print("The CV score is: ",lss_score,"\nThe accuracy score is:",lss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d77eae37c958> in <module>
# ----> 1 pred_lr=lr.predict(x_test)
#       2 lss=accuracy_score(y_test,pred_)
#       3 lss_score=cross_val_score(lr,x,y,cv=10).mean()
#       4 print("The CV score is: ",lss_score,"\nThe accuracy score is:",lss)
#
# NameError: name 'lr' is not defined

# %%
from sklearn.model_selection import GridSearchCV
parameters={'max_features':['auto','sqrt','log2'],
     'max_depth':[4,5,6,7,8],
           'criterion':['gini','entropy']}

gcv=GridSearchCV(lr,parameters,cv=10,scoring='accuracy')
gcv.fit(x_train,y_train)
gcv.best_params_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-817e709e9251> in <module>
#       4            'criterion':['gini','entropy']}
#       5
# ----> 6 gcv=GridSearchCV(lr,parameters,cv=10,scoring='accuracy')
#       7 gcv.fit(x_train,y_train)
#       8 gcv.best_params_
#
# NameError: name 'lr' is not defined

# %%
gcv_pred=gcv.best_estimator_.predict(x_test)
accuracy_score(y_test,gcv_pred)*100
# Out:
# 86.63749088256748

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(gcv.best_estimator_,x_test,y_test)
plt.title("ROC AUC Plot")
plt.show()

# %%
import joblib
joblib.dump(gcv.best_estimator_,"Census Income Project")
# Out:
# ['Census Income Project']
